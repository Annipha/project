# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("final raw data.csv")
data.head(5)
# Out:
#    Hamlet  Household_ID  Container_ID  Container_position  Water_level  Lid  \
# 0       0             1             1                   0           25    1
# 1       0             2             2                   1           25    1
# 2       0             2             5                   0           25    0
# 3       0             2             6                   0           25    1
# 4       0             3             5                   1           30    1
#
#    Fish  Meso  Micronecta  Source  Treatment  Larvae  Full count Larvae  \
# 0     0     0           0       0          0       1              206.7
# 1     0     0           0       1          0       0                0.0
# 2     0     0           0       1          0       0                0.0
# 3     0     0           0       0          1       0                0.0
# 4     0     0           0       0          1       0                0.0
#
#    Full count Pupae
# 0              51.6
# 1               3.0
# ...

# %%
hamlet_larvae = data[data['Larvae'] == 1]

sns.heatmap(hamlet_larvae[['Hamlet','Container_ID','Container_position','Water_level','Lid','Fish','Meso','Micronecta','Source','Treatment','Larvae','Full count Larvae']].corr())

# %%
from sklearn import linear_model

# %%
sns.regplot(x='Container_ID', y='Larvae', data=data,logistic=True)
